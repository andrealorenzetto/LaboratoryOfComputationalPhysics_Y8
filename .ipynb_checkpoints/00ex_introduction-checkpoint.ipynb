# %% [markdown]
# 1. The MickeyMouse problem
#
# a) Write a program that prints the numbers from 1 to 100. But for multiples of 3 print `Mickey` instead of the corresponding number and for the multiples of 5 print `Mouse`. For numbers which are multiples of both three and five print `MickeyMouse`
#
# b) Put the result in a tuple and substitute `Mickey` with `Donald` and `Mouse` with `Duck`

# %%
l = []
for i in range(1,101):
    #print(i)
    if(i % 3 == 0 and i % 5 != 0):
        l.append('Mickey')
    elif(i % 5 == 0 and i % 3 != 0):
        l.append('Mouse')
    elif(i % 5 == 0 and i % 3 == 0):
        l.append('Ciao')
    else:
        l.append(i)
print(l)
# Out:
# [1, 2, 'Mickey', 4, 'Mouse', 'Mickey', 7, 8, 'Mickey', 'Mouse', 11, 'Mickey', 13, 14, 'Ciao', 16, 17, 'Mickey', 19, 'Mouse', 'Mickey', 22, 23, 'Mickey', 'Mouse', 26, 'Mickey', 28, 29, 'Ciao', 31, 32, 'Mickey', 34, 'Mouse', 'Mickey', 37, 38, 'Mickey', 'Mouse', 41, 'Mickey', 43, 44, 'Ciao', 46, 47, 'Mickey', 49, 'Mouse', 'Mickey', 52, 53, 'Mickey', 'Mouse', 56, 'Mickey', 58, 59, 'Ciao', 61, 62, 'Mickey', 64, 'Mouse', 'Mickey', 67, 68, 'Mickey', 'Mouse', 71, 'Mickey', 73, 74, 'Ciao', 76, 77, 'Mickey', 79, 'Mouse', 'Mickey', 82, 83, 'Mickey', 'Mouse', 86, 'Mickey', 88, 89, 'Ciao', 91, 92, 'Mickey', 94, 'Mouse', 'Mickey', 97, 98, 'Mickey', 'Mouse']

# %% [markdown]
# 2\. The swap function
#
# Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable

# %%
def swap(x,y):
    c = x
    x = y
    y = c 
    return x,y
x = 5
y = 2
x,y = swap(x,y)
print(x, " ", y)
x,y = y,x
print(x, " ", y)
# Out:
# 2   5
# 5   2

# %% [markdown]
# 3\. Computing the distance
#
# Write a function that calculates and returns the euclidean distance between two points *u* and *v*, where *u* and *v* are both 2-tuples *(x,y)*. For example, if *u=(3,0)* and *v=(0,4)*, the function should return 5

# %% [markdown]
# 4\. Counting letters
#
# Write a program to calculate the number of times each character occurs in a given string *s*. Ignore differneces in capitalization

# %%
s="Write a program that prints the numbers from 1 to 100. \
But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. \
For numbers which are multiples of both three and five print MickeyMouse"
s1 = s.lower()
index = 0
dim = 0
while(dim < len(s1)):
    print(s1[index], ": ", s1.count(s1[index]))
    dim += s1.count(s1[index])
    index += 1
print(dim, " ", len(s1))
# Out:
# w :  2
# r :  17
# i :  14
# t :  19
# e :  22
#   :  41
# a :  7
#   :  41
# p :  8
# r :  17
# o :  13
# g :  1
# r :  17
# a :  7
# m :  12
# 238   232

# %% [markdown]
# 5\. Isolating the unique
#
# Write a function that determines and count the unique numbers in the list *l*

# %%
def unique_numbers(l):
    dim = 0
    index = 0
    aux = []
    while(dim < len(l)):
        if(l.count(l[index]) == 1):
            aux.append(l[index])
        dim += l.count(l[index])
        index += 1
    return aux
        
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]
print(len(unique_numbers(l)))
# Out:
# 21

# %% [markdown]
# 6\. Combination of functions
#
# Write two functions - one that returns the square of a number, and one that returns the cube. Now write a third function that returns the number raised to the 6th power using the two previous functions.

# %%
def square(x):
    return x*x
def cube(x):
    return x*x*x
def sixth(x):
    return cube(square(x))

x = 2
print(sixth(x))
# Out:
# 64

# %% [markdown]
# 7\. Cubes
#
# Create a list of the cubes of x for x in *[0, 10]* using:
#
# a) a for loop
#
# b) a list comprehension

# %%
x1 = range(11)
x = []
for t in x1:
    x.append(t**3)
print(x)
xc = [t**3 for t in x1]
print(xc)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %% [markdown]
# 8\. Nested list comprehension
#
# A Pythagorean triple is an integer solution to the Pythagorean theorem $a^2+b^2=c^2$. The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

# %%
l = [(a,b,int((a**2+b**2)**0.5)) for a in range(1,101) for b in range(a,101) if(range(1,101).count((a**2+b**2)**0.5) != 0)]
l
# Out:
# [(3, 4, 5),
#  (5, 12, 13),
#  (6, 8, 10),
#  (7, 24, 25),
#  (8, 15, 17),
#  (9, 12, 15),
#  (9, 40, 41),
#  (10, 24, 26),
#  (11, 60, 61),
#  (12, 16, 20),
#  (12, 35, 37),
#  (13, 84, 85),
#  (14, 48, 50),
#  (15, 20, 25),
#  (15, 36, 39),
#  (16, 30, 34),
#  (16, 63, 65),
#  (18, 24, 30),
#  (18, 80, 82),
#  (20, 21, 29),
#  (20, 48, 52),
#  (21, 28, 35),
#  (21, 72, 75),
#  (24, 32, 40),
#  (24, 45, 51),
#  (24, 70, 74),
#  (25, 60, 65),
#  (27, 36, 45),
#  (28, 45, 53),
#  (28, 96, 100),
#  (30, 40, 50),
#  (30, 72, 78),
#  (32, 60, 68),
#  (33, 44, 55),
#  (33, 56, 65),
#  (35, 84, 91),
#  (36, 48, 60),
#  (36, 77, 85),
#  (39, 52, 65),
#  (39, 80, 89),
#  (40, 42, 58),
#  (40, 75, 85),
#  (42, 56, 70),
#  (45, 60, 75),
#  (48, 55, 73),
#  (48, 64, 80),
#  (51, 68, 85),
#  (54, 72, 90),
#  (57, 76, 95),
#  (60, 63, 87),
#  (60, 80, 100),
#  (65, 72, 97)]

# %% [markdown]
# 9\. Normalization
#
# Write a function that takes a tuple of numbers and returns it with the entries normalized to one

# %%
l = [2,5,1,7,9,4,3,6,5,3,7,8,10]
nl = [elem/sum(l) for elem in l]
print(nl)
# Out:
# 1.0
